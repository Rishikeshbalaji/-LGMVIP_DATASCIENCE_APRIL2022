# %% [markdown]
# LGMVIP-DataScience Internship - February 2022
#
# Beginner level-TASK-4 Image to Pencil Sketch with Python
#
#
#
# Importing Libraries

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# Reading the image

# %%
fish_image = cv2.imread("frog.jpg")
cv2_imshow(fish_image)
# Out:
# <PIL.Image.Image image mode=RGB size=385x393 at 0x7F24A05D8F10>

# %% [markdown]
# Read the image in RBG format

# %%
rbg = cv2.cvtColor(fish_image, cv2.COLOR_BGR2RGB)
cv2_imshow(rbg)
# Out:
# <PIL.Image.Image image mode=RGB size=385x393 at 0x7F24A0570B10>

# %% [markdown]
# convert RBG format to grayscale image

# %%
gray_scale = cv2.cvtColor(rbg, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale)
# Out:
# <PIL.Image.Image image mode=L size=385x393 at 0x7F24A057DD50>

# %% [markdown]
# Inverted grayscale image(Negative image)

# %%
inverted_gray_scale = 255 - gray_scale
cv2_imshow(inverted_gray_scale )
# Out:
# <PIL.Image.Image image mode=L size=385x393 at 0x7F24A058F050>

# %% [markdown]
# Blurry image

# %%
blur_image = cv2.GaussianBlur(inverted_gray_scale, (21,21), 0)
cv2_imshow(blur_image)
# Out:
# <PIL.Image.Image image mode=L size=385x393 at 0x7F24A0570D50>

# %% [markdown]
# Inverted blurry image

# %%
inverted_blur = 255 - blur_image
cv2_imshow(inverted_blur)
# Out:
# <PIL.Image.Image image mode=L size=385x393 at 0x7F24A057DAD0>

# %% [markdown]
# Pencil Sketch

# %%
pencil_sketch = cv2.divide(gray_scale, inverted_blur, scale=255)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=385x393 at 0x7F24A056AD90>
